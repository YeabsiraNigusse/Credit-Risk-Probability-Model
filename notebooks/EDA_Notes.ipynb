# %% [markdown]
# ### Explanatory Data Analysis(EDA) with Pandas(CheatSheet)

# %% [markdown]
# #### Data Loading

# %%
import pandas as pd

# %%
df = pd.read_csv("filename.csv") # Read CSV file
df = pd.read_excel("filename.xlsx") # Read excel file
df = pd.read_sql(query, connection) # Read from SQL Database

# %% [markdown]
# #### Basic Data Inspection

# %%
df.head() # Display top rows
df.tail() # Display bottom rows
df.dtypes # Display data types
df.describe() # Summary Statistics
df.info() # Display Index, Columns, and Data


# More of reading the column names and understanding what they mean is more helpfull than looking the data statistics

# %% [markdown]
# #### Data Cleaning

# %%
df.isnull().sum() # Check for missing values
df.fillna(value) # fill missing values
df.dropna() # Drop missing values
df.rename(columns={'old_name': 'new_name'}) # rename columns
df.drop(columns=['column_name']) # Drop column
